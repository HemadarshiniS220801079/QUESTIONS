# %%
names=["  alpha Case  ", "Beta   unit", "gAmMa MODULE  "]
a=list(map(lambda x:x.strip().title(),names))
print(a)
# Out:
# ['Alpha Case', 'Beta   Unit', 'Gamma Module']

# %%
from functools import reduce

price = list(map(int, input().split()))

a = reduce(
    lambda x, y: x + y,
    filter(
        lambda x: x >= 200,
        map(lambda x: x * 0.90, price)
    )
)

print(a)
# Out:
# 100 200 350
# 315.0

# %%
from functools import reduce

scores  = list(map(int,input().split()))
weights = list(map(float,input().split()))

weighted_sum = reduce(
    lambda acc, i: acc + scores[i] * weights[i],
    range(1, len(scores)),
    scores[0] * weights[0]
)

total_weight = reduce(lambda x, y: x + y, weights)

weighted_average = weighted_sum / total_weight

print(weighted_average)
# Out:
# 40 30 50 70
# 1.2 3.4 5.0 6.0
# 52.56410256410256
